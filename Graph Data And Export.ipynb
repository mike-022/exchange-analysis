# %%
pip install -r requirements.txt

# %%
# %run -i 'gather_tickers.py'
# Out:
# SUSHI: SUSHI-GBP, SUSHI-USD, SUSHI-ETH, SUSHI-BTC, SUSHI-EUR,
# NU: NU-EUR, NU-USD, NU-BTC, NU-GBP,
# CTSI: CTSI-USD, CTSI-BTC,
# MATIC: MATIC-GBP, MATIC-EUR, MATIC-USD, MATIC-BTC,
# ALGO: ALGO-BTC, ALGO-GBP, ALGO-EUR, ALGO-USD,
# XLM: XLM-USD, XLM-EUR, XLM-BTC,
# BAND: BAND-GBP, BAND-USD, BAND-EUR, BAND-BTC,
# DASH: DASH-USD, DASH-BTC,
# GNT: GNT-USDC,
# OGN: OGN-BTC, OGN-USD,
# LTC: LTC-GBP, LTC-USD, LTC-BTC, LTC-EUR,
# UMA: UMA-BTC, UMA-EUR, UMA-GBP, UMA-USD,
# ENJ: ENJ-USD, ENJ-BTC,
# OMG: OMG-BTC, OMG-USD, OMG-GBP, OMG-EUR,
# DAI: DAI-USD, DAI-USDC,
# FIL: FIL-GBP, FIL-BTC, FIL-EUR, FIL-USD,
# CGLD: CGLD-EUR, CGLD-USD, CGLD-GBP, CGLD-BTC,
# ANKR: ANKR-BTC, ANKR-EUR, ANKR-USD, ANKR-GBP,
# LINK: LINK-ETH, LINK-GBP, LINK-BTC, LINK-EUR, LINK-USD,
# MKR: MKR-BTC, MKR-USD,
# EOS: EOS-BTC, EOS-EUR, EOS-USD,
# ADA: ADA-GBP, ADA-ETH, ADA-USDC, ADA-BTC, ADA-EUR, ADA-USD,
# SNX: SNX-EUR, SNX-BTC, SNX-GBP, SNX-USD,
# BAT: BAT-USDC, BAT-USD, BAT-BTC, BAT-EUR, BAT-ETH,
# BNT: BNT-USD, BNT-GBP, BNT-EUR, BNT-BTC,
# TRB: TRB-BTC, TRB-USD,
# MANA: MANA-EUR, MANA-USD, MANA-BTC, MANA-USDC, MANA-ETH,
# FORTH: FORTH-EUR, FORTH-USD, FORTH-BTC, FORTH-GBP,
# WBTC: WBTC-BTC, WBTC-USD,
# REN: REN-USD, REN-BTC,
# ATOM: ATOM-USD, ATOM-BTC,
# USDT: USDT-EUR, USDT-USD, USDT-USDC, USDT-GBP,
# MIR: MIR-BTC, MIR-EUR, MIR-GBP, MIR-USD,
# SKL: SKL-BTC, SKL-USD, SKL-GBP, SKL-EUR,
# BCH: BCH-EUR, BCH-USD, BCH-BTC, BCH-GBP,
# DOGE: DOGE-USD, DOGE-GBP, DOGE-EUR, DOGE-USDT, DOGE-BTC,
# AAVE: AAVE-GBP, AAVE-BTC, AAVE-USD, AAVE-EUR,
# ETH: ETH-USD, ETH-GBP, ETH-DAI, ETH-USDT, ETH-USDC, ETH-BTC, ETH-EUR,
# ZEC: ZEC-BTC, ZEC-USD, ZEC-USDC,
# XTZ: XTZ-BTC, XTZ-GBP, XTZ-EUR, XTZ-USD,
# CVC: CVC-USDC,
# NMR: NMR-BTC, NMR-EUR, NMR-GBP, NMR-USD,
# OXT: OXT-USD,
# KNC: KNC-USD, KNC-BTC,
# LRC: LRC-USD, LRC-BTC,
# REP: REP-BTC, REP-USD,
# ETC: ETC-GBP, ETC-BTC, ETC-USD, ETC-EUR,
# LOOM: LOOM-USDC,
# COMP: COMP-BTC, COMP-USD,
# CRV: CRV-GBP, CRV-USD, CRV-EUR, CRV-BTC,
# GRT: GRT-USD, GRT-BTC, GRT-GBP, GRT-EUR,
# ZRX: ZRX-USD, ZRX-EUR, ZRX-BTC,
# BAL: BAL-USD, BAL-BTC,
# 1INCH: 1INCH-GBP, 1INCH-BTC, 1INCH-EUR, 1INCH-USD,
# DNT: DNT-USDC,
# BTC: BTC-GBP, BTC-USDT, BTC-EUR, BTC-USD, BTC-USDC,
# YFI: YFI-USD, YFI-BTC,
# ICP: ICP-EUR, ICP-GBP, ICP-USD, ICP-BTC, ICP-USDT,
# STORJ: STORJ-USD, STORJ-BTC,
# UNI: UNI-USD, UNI-BTC,
# NKN: NKN-BTC, NKN-USD,
# RLC: RLC-USD, RLC-BTC,
# USDC: USDC-GBP, USDC-EUR,

# %%
## Graph plots

import time 
import finplot as fplt
import numpy as np
import pandas as pd
import cbpro
import talib

#[60, 300, 900, 3600, 21600, 86400]
public_client = cbpro.PublicClient()
acceptedGrans = {"1m":60,"5m":300,"15m":900,"1h":3600,"6h":21600,"1d":86400}

ids = input("Please enter product id(s), comma separated.")
start = input("Start date in yyyy-mm-dd format")
end = input("End date in yyyy-mm-dd format")
granularity = input("Enter timeframe: [1m,5m,15m,1h,6h,1d]")

# ids="ETH-BTC,LINK-ETH"
# start ="2021-01-01"
# end = "2021-06-01"
# granularity= "1d"


gran = acceptedGrans[str(granularity)]

product_ids_to_add = ids.split(",")


ohlcv_dictonary = {}
for product_id in product_ids_to_add:
    ohlcv = public_client.get_product_historic_rates(product_id,start,end,gran)
    df = pd.DataFrame(ohlcv, columns = ['time', 'low','high','open','close','volume']) 
    # create two axes
    ax,ax2 = fplt.create_plot(product_id, rows=2)

    # plot candle sticks
    candles = df[['time','open','close','high','low']]
    fplt.candlestick_ochl(candles, ax=ax)
    
    #Plot volume
    volumes = df[['time','open','close','volume']]
    fplt.volume_ocv(volumes, ax=ax.overlay())
    
    
    ohlcv_dictonary[str(product_id)]= ohlcv
    time.sleep(1)# Don't want to send too many requests at a time to the public coinbase api
    
fplt.show()
