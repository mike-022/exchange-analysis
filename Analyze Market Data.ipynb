# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: cbpro in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (1.1.4)
# Requirement already satisfied: jupyter in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (1.0.0)
# Requirement already satisfied: finplot in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (1.7)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (1.2.4)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (1.20.2)
# Requirement already satisfied: six==1.10.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from cbpro->-r requirements.txt (line 1)) (1.10.0)
# Requirement already satisfied: requests==2.13.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from cbpro->-r requirements.txt (line 1)) (2.13.0)
# Requirement already satisfied: sortedcontainers>=1.5.9 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from cbpro->-r requirements.txt (line 1)) (2.4.0)
# Requirement already satisfied: websocket-client==0.40.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from cbpro->-r requirements.txt (line 1)) (0.40.0)
# Requirement already satisfied: pymongo==3.5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from cbpro->-r requirements.txt (line 1)) (3.5.1)
# Requirement already satisfied: ipykernel in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyter->-r requirements.txt (line 2)) (5.5.5)
# Requirement already satisfied: nbconvert in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyter->-r requirements.txt (line 2)) (6.0.7)
# Requirement already satisfied: jupyter-console in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyter->-r requirements.txt (line 2)) (6.4.0)
# Requirement already satisfied: qtconsole in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyter->-r requirements.txt (line 2)) (5.1.0)
# Requirement already satisfied: ipywidgets in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyter->-r requirements.txt (line 2)) (7.6.3)
# Requirement already satisfied: notebook in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyter->-r requirements.txt (line 2)) (6.4.0)
# Requirement already satisfied: pyqtgraph>=0.11.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from finplot->-r requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: PyQt5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from finplot->-r requirements.txt (line 3)) (5.15.4)
# Requirement already satisfied: pytz>=2017.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pandas->-r requirements.txt (line 4)) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pandas->-r requirements.txt (line 4)) (2.8.1)
# Requirement already satisfied: appnope; platform_system == "Darwin" in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipykernel->jupyter->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: ipython>=5.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipykernel->jupyter->-r requirements.txt (line 2)) (7.24.1)
# Requirement already satisfied: traitlets>=4.1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipykernel->jupyter->-r requirements.txt (line 2)) (5.0.5)
# Requirement already satisfied: jupyter-client in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipykernel->jupyter->-r requirements.txt (line 2)) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipykernel->jupyter->-r requirements.txt (line 2)) (6.1)
# Requirement already satisfied: nbformat>=4.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert->jupyter->-r requirements.txt (line 2)) (5.1.3)
# Requirement already satisfied: bleach in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert->jupyter->-r requirements.txt (line 2)) (3.3.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert->jupyter->-r requirements.txt (line 2)) (0.8.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert->jupyter->-r requirements.txt (line 2)) (0.5.3)
# Requirement already satisfied: defusedxml in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert->jupyter->-r requirements.txt (line 2)) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert->jupyter->-r requirements.txt (line 2)) (0.3)
# Requirement already satisfied: jinja2>=2.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert->jupyter->-r requirements.txt (line 2)) (3.0.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert->jupyter->-r requirements.txt (line 2)) (1.4.3)
# Requirement already satisfied: testpath in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert->jupyter->-r requirements.txt (line 2)) (0.5.0)
# Requirement already satisfied: pygments>=2.4.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert->jupyter->-r requirements.txt (line 2)) (2.9.0)
# Requirement already satisfied: jupyter-core in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert->jupyter->-r requirements.txt (line 2)) (4.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert->jupyter->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyter-console->jupyter->-r requirements.txt (line 2)) (3.0.18)
# Requirement already satisfied: qtpy in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from qtconsole->jupyter->-r requirements.txt (line 2)) (1.9.0)
# Requirement already satisfied: ipython-genutils in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from qtconsole->jupyter->-r requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: pyzmq>=17.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from qtconsole->jupyter->-r requirements.txt (line 2)) (22.1.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0; python_version >= "3.6" in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipywidgets->jupyter->-r requirements.txt (line 2)) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipywidgets->jupyter->-r requirements.txt (line 2)) (3.5.1)
# Requirement already satisfied: Send2Trash>=1.5.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from notebook->jupyter->-r requirements.txt (line 2)) (1.5.0)
# Requirement already satisfied: terminado>=0.8.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from notebook->jupyter->-r requirements.txt (line 2)) (0.10.0)
# Requirement already satisfied: prometheus-client in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from notebook->jupyter->-r requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: argon2-cffi in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from notebook->jupyter->-r requirements.txt (line 2)) (20.1.0)
# Requirement already satisfied: PyQt5-Qt5>=5.15 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from PyQt5->finplot->-r requirements.txt (line 3)) (5.15.2)
# Requirement already satisfied: PyQt5-sip<13,>=12.8 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from PyQt5->finplot->-r requirements.txt (line 3)) (12.9.0)
# Requirement already satisfied: matplotlib-inline in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython>=5.0.0->ipykernel->jupyter->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: decorator in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython>=5.0.0->ipykernel->jupyter->-r requirements.txt (line 2)) (5.0.9)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython>=5.0.0->ipykernel->jupyter->-r requirements.txt (line 2)) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython>=5.0.0->ipykernel->jupyter->-r requirements.txt (line 2)) (49.2.1)
# Requirement already satisfied: backcall in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython>=5.0.0->ipykernel->jupyter->-r requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython>=5.0.0->ipykernel->jupyter->-r requirements.txt (line 2)) (0.18.0)
# Requirement already satisfied: pickleshare in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython>=5.0.0->ipykernel->jupyter->-r requirements.txt (line 2)) (0.7.5)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbformat>=4.4->nbconvert->jupyter->-r requirements.txt (line 2)) (3.2.0)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from bleach->nbconvert->jupyter->-r requirements.txt (line 2)) (20.9)
# Requirement already satisfied: webencodings in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from bleach->nbconvert->jupyter->-r requirements.txt (line 2)) (0.5.1)
# Requirement already satisfied: nest-asyncio in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter->-r requirements.txt (line 2)) (1.5.1)
# Requirement already satisfied: async-generator in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter->-r requirements.txt (line 2)) (1.10)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jinja2>=2.4->nbconvert->jupyter->-r requirements.txt (line 2)) (2.0.1)
# Requirement already satisfied: wcwidth in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter->-r requirements.txt (line 2)) (0.2.5)
# Requirement already satisfied: ptyprocess; os_name != "nt" in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from terminado>=0.8.3->notebook->jupyter->-r requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: cffi>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from argon2-cffi->notebook->jupyter->-r requirements.txt (line 2)) (1.14.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel->jupyter->-r requirements.txt (line 2)) (0.8.2)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert->jupyter->-r requirements.txt (line 2)) (0.16.1)
# Requirement already satisfied: attrs>=17.4.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert->jupyter->-r requirements.txt (line 2)) (21.2.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from packaging->bleach->nbconvert->jupyter->-r requirements.txt (line 2)) (2.4.7)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->notebook->jupyter->-r requirements.txt (line 2)) (2.20)
# WARNING: You are using pip version 20.2.3; however, version 21.1.2 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# Get Product ids from coinbase api
# %run -i 'gather_tickers.py'
# Out:
# 1INCH: 1INCH-USD, 1INCH-GBP, 1INCH-EUR, 1INCH-BTC,
# AAVE: AAVE-USD, AAVE-GBP, AAVE-BTC, AAVE-EUR,
# ZRX: ZRX-EUR, ZRX-USD, ZRX-BTC,
# REP: REP-USD, REP-BTC,
# BTC: BTC-EUR, BTC-USD, BTC-GBP, BTC-USDC, BTC-USDT,
# CTSI: CTSI-USD, CTSI-BTC,
# LTC: LTC-GBP, LTC-BTC, LTC-USD, LTC-EUR,
# FORTH: FORTH-GBP, FORTH-USD, FORTH-EUR, FORTH-BTC,
# DAI: DAI-USDC, DAI-USD,
# FIL: FIL-BTC, FIL-EUR, FIL-USD, FIL-GBP,
# MIR: MIR-USD, MIR-BTC, MIR-GBP, MIR-EUR,
# NMR: NMR-EUR, NMR-BTC, NMR-USD, NMR-GBP,
# SKL: SKL-EUR, SKL-BTC, SKL-USD, SKL-GBP,
# SNX: SNX-BTC, SNX-EUR, SNX-USD, SNX-GBP,
# NU: NU-BTC, NU-USD, NU-EUR, NU-GBP,
# ICP: ICP-USD, ICP-USDT, ICP-GBP, ICP-BTC, ICP-EUR,
# XLM: XLM-USD, XLM-EUR, XLM-BTC,
# UNI: UNI-USD, UNI-BTC,
# ATOM: ATOM-USD, ATOM-BTC,
# NKN: NKN-BTC, NKN-USD,
# MANA: MANA-EUR, MANA-USD, MANA-BTC, MANA-ETH, MANA-USDC,
# UMA: UMA-EUR, UMA-USD, UMA-GBP, UMA-BTC,
# USDT: USDT-GBP, USDT-USDC, USDT-USD, USDT-EUR,
# REN: REN-BTC, REN-USD,
# XTZ: XTZ-GBP, XTZ-BTC, XTZ-EUR, XTZ-USD,
# BAND: BAND-BTC, BAND-EUR, BAND-USD, BAND-GBP,
# GRT: GRT-BTC, GRT-EUR, GRT-USD, GRT-GBP,
# LINK: LINK-GBP, LINK-ETH, LINK-USD, LINK-BTC, LINK-EUR,
# CGLD: CGLD-GBP, CGLD-BTC, CGLD-EUR, CGLD-USD,
# CRV: CRV-BTC, CRV-USD, CRV-EUR, CRV-GBP,
# ANKR: ANKR-USD, ANKR-EUR, ANKR-BTC, ANKR-GBP,
# STORJ: STORJ-USD, STORJ-BTC,
# MKR: MKR-BTC, MKR-USD,
# EOS: EOS-BTC, EOS-USD, EOS-EUR,
# RLC: RLC-BTC, RLC-USD,
# OMG: OMG-USD, OMG-EUR, OMG-BTC, OMG-GBP,
# ALGO: ALGO-GBP, ALGO-EUR, ALGO-USD, ALGO-BTC,
# DOGE: DOGE-BTC, DOGE-USD, DOGE-EUR, DOGE-USDT, DOGE-GBP,
# ZEC: ZEC-BTC, ZEC-USDC, ZEC-USD,
# GNT: GNT-USDC,
# ETH: ETH-USDT, ETH-GBP, ETH-BTC, ETH-EUR, ETH-USD, ETH-USDC, ETH-DAI,
# BNT: BNT-BTC, BNT-USD, BNT-EUR, BNT-GBP,
# MATIC: MATIC-GBP, MATIC-BTC, MATIC-USD, MATIC-EUR,
# BAT: BAT-BTC, BAT-ETH, BAT-USD, BAT-USDC, BAT-EUR,
# BCH: BCH-USD, BCH-EUR, BCH-BTC, BCH-GBP,
# ADA: ADA-USD, ADA-EUR, ADA-BTC, ADA-GBP, ADA-USDC, ADA-ETH,
# ETC: ETC-EUR, ETC-GBP, ETC-BTC, ETC-USD,
# LRC: LRC-USD, LRC-BTC,
# DNT: DNT-USDC,
# ENJ: ENJ-BTC, ENJ-USD,
# OGN: OGN-USD, OGN-BTC,
# TRB: TRB-BTC, TRB-USD,
# YFI: YFI-USD, YFI-BTC,
# KNC: KNC-BTC, KNC-USD,
# LOOM: LOOM-USDC,
# BAL: BAL-USD, BAL-BTC,
# CVC: CVC-USDC,
# SUSHI: SUSHI-EUR, SUSHI-BTC, SUSHI-ETH, SUSHI-GBP, SUSHI-USD,
# COMP: COMP-BTC, COMP-USD,
# USDC: USDC-GBP, USDC-EUR,
# WBTC: WBTC-USD, WBTC-BTC,
# OXT: OXT-USD,
# DASH: DASH-BTC, DASH-USD,

# %%
## Run technical analysis and pattern analysis on historical data
## Requires talib installation to run
## Adding a few basic indicators for the sake of test but can easily add more

import time 
import numpy as np
import pandas as pd
import cbpro
import talib
import datetime
import utils.validator as v

public_client = cbpro.PublicClient()
acceptedGrans = {"1m":60,"5m":300,"15m":900,"1h":3600,"6h":21600,"1d":86400}


# For the sake of simplicity we will fail over if the requested data set is too big.
# For an enhanced product, including if we  
ids = input("Please enter product id(s), comma separated i.e.'ETH-BTC,LINK-ETH': ")
start = input("Start date in yyyy-mm-dd format: ")
end = input("End date in yyyy-mm-dd format: ")
granularity = input("Enter timeframe: [1m,5m,15m,1h,6h,1d]: ")

#Hardcoded
# ids="ETH-BTC,LINK-ETH"
# start ="2021-01-01"
# end = "2021-06-01"
# granularity= "1d"


gran = acceptedGrans[str(granularity)]

product_ids_to_add = ids.split(",")

# Creating a dictionary for future comparisons of data streams
ohlcv_dictonary = {}
for product_id in product_ids_to_add:
    ohlcv = public_client.get_product_historic_rates(product_id,start,end,gran)
    df = pd.DataFrame(ohlcv, columns = ['time', 'low','high','open','close','volume']) 

    ohlcv_dictonary[str(product_id)]= df

    #DOJI Technical pattern
    CDL3BLACKCROWS = talib.CDL3BLACKCROWS(df['open'], df['high'], df['low'], df['close'])
    MFI = talib.MFI(df['high'], df['low'], df['close'], df['volume'], timeperiod=14)
    doji = talib.CDLDOJI(df['open'], df['high'], df['low'], df['close'])
    ohlcv_dictonary[str(product_id)]["doji_count"] = doji[doji!=0].size
    print(product_id + " has " + str(doji[doji!=0].size) + " doji candles from " + start + " to " + end + " on the " + granularity + "."  )

    #Cycle indicator
    real = talib.HT_DCPHASE(df['close'])
    print(product_id + " has " + str(real[real>100].size) + " candles above 250 hilbert dominant phase from " + start + " to " + end + " on the " + granularity + "."  )

    #Volume indicators
    onbalancevolume = talib.OBV(df['close'], df['volume'])
    chaikinadoscillator = talib.ADOSC(df['high'], df['low'], df['close'], df['volume'], fastperiod=3, slowperiod=10)
    
    

    time.sleep(1)# Don't want to send too many requests at a time to the public coinbase api
# Out:
# Please enter product id(s), comma separated: ETH-BTC,LINK-ETH,LINK-BTC
# Start date in yyyy-mm-dd format: 2021-05-01
# End date in yyyy-mm-dd format: 2021-06-01
# Enter timeframe: ,5m,15m,1h,6h,1d]: 6h
# ETH-BTC has 20 doji candles from 2021-05-01 to 2021-06-01 on the 6h.
# ETH-BTC has 17 days above 250 hilbert dominant phase from 2021-05-01 to 2021-06-01 on the 6h.
# LINK-ETH has 20 doji candles from 2021-05-01 to 2021-06-01 on the 6h.
# LINK-ETH has 45 days above 250 hilbert dominant phase from 2021-05-01 to 2021-06-01 on the 6h.
# LINK-BTC has 20 doji candles from 2021-05-01 to 2021-06-01 on the 6h.
# LINK-BTC has 30 days above 250 hilbert dominant phase from 2021-05-01 to 2021-06-01 on the 6h.

# %%
# Export chart data to csv.
import zipfile
import os
if not os.path.exists('output'):
    os.makedirs('output')

    
zipname= ids+"_from_"+start+"_to_"+end+".zip"
with zipfile.ZipFile("output/"+zipname, 'w') as csv_zip:
    for key in ohlcv_dictonary:
        dataframe_to_write = ohlcv_dictonary[str(key)]
        print(key)
        csv_zip.writestr(key+".csv", dataframe_to_write.to_csv())

print("Exported csvs to zip.")
# Out:
# ETH-BTC
# Exported csvs to zip.
